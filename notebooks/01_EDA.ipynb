# %% [markdown]
# # Exploratory Data Analysis
#
# Use this notebook to inspect the experiment inputs and sanity-check the data.

# %%
from ab_testing_framework.analysis import run_ab_test
result = run_ab_test(10000, 450, 10000, 520)
result.summary
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ab_testing_framework.analysis import run_ab_test
#       2 result = run_ab_test(10000, 450, 10000, 520)
#       3 result.summary
#
# ModuleNotFoundError: No module named 'ab_testing_framework'
